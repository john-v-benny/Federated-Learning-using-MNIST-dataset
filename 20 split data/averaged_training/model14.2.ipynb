# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
print("Loading test and train data part 14")
data_part = np.load("..\mnist_split_data_20\mnist_part14.npz")
x_train = data_part['x_train']
y_train = data_part['y_train']
x_test = data_part['x_test']
y_test = data_part['y_test']
print(f"Loaded {x_test.shape[0]} test samples. and {x_train.shape[0]} train samples")
# Out:
# Loading test and train data part 14
# Loaded 501 test samples. and 2999 train samples

# %%
print("\nLoading model architecture from model14.h5...")
model = keras.models.load_model('..\saved_models\mnist_model_v14.h5')
print("model loaded successfully.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loading model architecture from model14.h5...
# model loaded successfully.

# %%
print("Setting average weights from average_weights.h5...")
model.load_weights('../saved_models/averaged.weights.h5')
print("✅ Successfully set the average weights into the model!")
# Out:
# Setting average weights from average_weights.h5...
# ✅ Successfully set the average weights into the model!
# d:\amrita intern\tfenv\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
x_train = x_train / 255
x_test = x_test / 255

x_train_flatten = x_train.reshape(len(x_train), 28*28)
x_test_flatten = x_test.reshape(len(x_test), 28*28)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Optimized learning rate
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("model compiled successfully.")
# Out:
# model compiled successfully.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 112,042 (437.66 KB)
#  Trainable params: 111,594 (435.91 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    x_train_flatten, y_train,
    epochs=30,          
    batch_size=64,     
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6565 - loss: 1.4765 - val_accuracy: 0.1067 - val_loss: 2.1775
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8181 - loss: 1.0045 - val_accuracy: 0.3433 - val_loss: 2.0015
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8611 - loss: 0.7758 - val_accuracy: 0.7933 - val_loss: 1.7683
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8818 - loss: 0.6309 - val_accuracy: 0.8233 - val_loss: 1.4813
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8963 - loss: 0.5381 - val_accuracy: 0.7600 - val_loss: 1.2761
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9089 - loss: 0.4570 - val_accuracy: 0.8000 - val_loss: 1.0152
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.4255 - val_accuracy: 0.8333 - val_loss: 0.7598
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9133 - loss: 0.3885 - val_accuracy: 0.8367 - val_loss: 0.6142
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9226 - loss: 0.3398 - val_accuracy: 0.8433 - val_loss: 0.5484
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9211 - loss: 0.3185 - val_accuracy: 0.8167 - val_loss: 0.6210
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9203 - loss: 0.3075 - val_accuracy: 0.7767 - val_loss: 0.6698
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9322 - loss: 0.2904 - val_accuracy: 0.8133 - val_loss: 0.5961
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.2655 - val_accuracy: 0.8333 - val_loss: 0.5942
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9359 - loss: 0.2461 - val_accuracy: 0.8533 - val_loss: 0.4956
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9418 - loss: 0.2371 - val_accuracy: 0.8733 - val_loss: 0.3893
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9429 - loss: 0.2163 - val_accuracy: 0.8633 - val_loss: 0.4202
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9444 - loss: 0.2134 - val_accuracy: 0.8367 - val_loss: 0.5603
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9466 - loss: 0.2096 - val_accuracy: 0.8433 - val_loss: 0.5538
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.2004 - val_accuracy: 0.8633 - val_loss: 0.5060
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9481 - loss: 0.1893 - val_accuracy: 0.8567 - val_loss: 0.4505
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.1937 - val_accuracy: 0.8500 - val_loss: 0.4557
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9500 - loss: 0.1759 - val_accuracy: 0.8567 - val_loss: 0.4766
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.1778 - val_accuracy: 0.8767 - val_loss: 0.4456
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9511 - loss: 0.1654 - val_accuracy: 0.8733 - val_loss: 0.4305
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9537 - loss: 0.1645 - val_accuracy: 0.8333 - val_loss: 0.6032
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9522 - loss: 0.1655 - val_accuracy: 0.8533 - val_loss: 0.4864
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.1447 - val_accuracy: 0.8700 - val_loss: 0.4867
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9570 - loss: 0.1524 - val_accuracy: 0.8667 - val_loss: 0.4537
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1449 - val_accuracy: 0.8700 - val_loss: 0.4610
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.1519 - val_accuracy: 0.8767 - val_loss: 0.4787

# %%
print("\nEvaluating the model on the test set...")
test_loss, test_accuracy = model.evaluate(x_test_flatten, y_test, verbose=2)

# Get final training accuracy from history
train_accuracy = history.history['accuracy'][-1]

print("\n" + "="*60)
print(f"🎯 Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"🎯 Test Accuracy:     {test_accuracy * 100:.2f}%")
print(f"   Difference:        {abs(train_accuracy - test_accuracy) * 100:.2f}%")
print("="*60)
# Out:
# Evaluating the model on the test set...
# 16/16 - 0s - 2ms/step - accuracy: 0.9222 - loss: 0.3232
#
# ============================================================
# 🎯 Training Accuracy: 96.07%
# 🎯 Test Accuracy:     92.22%
#    Difference:        3.86%
# ============================================================
