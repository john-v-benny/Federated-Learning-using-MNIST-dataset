# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
print("Loading test and train data part 2")
data_part = np.load("..\mnist_split_data_5\mnist_part2.npz")
x_train = data_part['x_train']
y_train = data_part['y_train']
x_test = data_part['x_test']
y_test = data_part['y_test']
print(f"Loaded {x_test.shape[0]} test samples. and {x_train.shape[0]} train samples")
# Out:
# Loading test and train data part 2
# Loaded 2001 test samples. and 11999 train samples

# %%
print("\nLoading model architecture from model2.h5...")
model = keras.models.load_model('..\saved_models\mnist_model_v2.h5')
print("model loaded successfully.")
# Out:
# Loading model architecture from model2.h5...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model loaded successfully.

# %%
print("Setting average weights from average_weights.h5...")
model.load_weights('../saved_models/averaged.weights.h5')
print("✅ Successfully set the average weights into the model!")
# Out:
# Setting average weights from average_weights.h5...
# ✅ Successfully set the average weights into the model!
# d:\amrita intern\tfenv\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
x_train = x_train / 255
x_test = x_test / 255

x_train_flatten = x_train.reshape(len(x_train), 28*28)
x_test_flatten = x_test.reshape(len(x_test), 28*28)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Optimized learning rate
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("model compiled successfully.")
# Out:
# model compiled successfully.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 112,042 (437.66 KB)
#  Trainable params: 111,594 (435.91 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    x_train_flatten, y_train,
    epochs=30,          
    batch_size=64,     
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7772 - loss: 0.7803 - val_accuracy: 0.8892 - val_loss: 0.6952
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8811 - loss: 0.4434 - val_accuracy: 0.8850 - val_loss: 0.4230
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9016 - loss: 0.3643 - val_accuracy: 0.8975 - val_loss: 0.3462
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9024 - loss: 0.3346 - val_accuracy: 0.9158 - val_loss: 0.2823
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9087 - loss: 0.3119 - val_accuracy: 0.9333 - val_loss: 0.2347
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9083 - loss: 0.3079 - val_accuracy: 0.9383 - val_loss: 0.2140
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9167 - loss: 0.2796 - val_accuracy: 0.9367 - val_loss: 0.2157
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9226 - loss: 0.2586 - val_accuracy: 0.9325 - val_loss: 0.2163
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9247 - loss: 0.2555 - val_accuracy: 0.9200 - val_loss: 0.2575
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9258 - loss: 0.2494 - val_accuracy: 0.9192 - val_loss: 0.2784
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9255 - loss: 0.2442 - val_accuracy: 0.9225 - val_loss: 0.2503
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9303 - loss: 0.2276 - val_accuracy: 0.9425 - val_loss: 0.1965
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9309 - loss: 0.2274 - val_accuracy: 0.9408 - val_loss: 0.1893
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9309 - loss: 0.2209 - val_accuracy: 0.9275 - val_loss: 0.2206
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9340 - loss: 0.2117 - val_accuracy: 0.9508 - val_loss: 0.1771
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9421 - loss: 0.1938 - val_accuracy: 0.9142 - val_loss: 0.3043
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9366 - loss: 0.2112 - val_accuracy: 0.9467 - val_loss: 0.1885
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9414 - loss: 0.1988 - val_accuracy: 0.9475 - val_loss: 0.1861
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9380 - loss: 0.1985 - val_accuracy: 0.9367 - val_loss: 0.2315
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9407 - loss: 0.1911 - val_accuracy: 0.9425 - val_loss: 0.1893
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9421 - loss: 0.1940 - val_accuracy: 0.9542 - val_loss: 0.1604
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9437 - loss: 0.1793 - val_accuracy: 0.9525 - val_loss: 0.1710
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9474 - loss: 0.1781 - val_accuracy: 0.9500 - val_loss: 0.1723
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9468 - loss: 0.1785 - val_accuracy: 0.9542 - val_loss: 0.1813
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9450 - loss: 0.1698 - val_accuracy: 0.9575 - val_loss: 0.1642
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9443 - loss: 0.1786 - val_accuracy: 0.9492 - val_loss: 0.1725
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9449 - loss: 0.1684 - val_accuracy: 0.9483 - val_loss: 0.1936
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9478 - loss: 0.1704 - val_accuracy: 0.9408 - val_loss: 0.1881
# Epoch 29/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9496 - loss: 0.1626 - val_accuracy: 0.9525 - val_loss: 0.1752
# Epoch 30/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9511 - loss: 0.1642 - val_accuracy: 0.9550 - val_loss: 0.1541

# %%
print("\nEvaluating the model on the test set...")
test_loss, test_accuracy = model.evaluate(x_test_flatten, y_test, verbose=2)

# Get final training accuracy from history
train_accuracy = history.history['accuracy'][-1]

print("\n" + "="*60)
print(f"🎯 Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"🎯 Test Accuracy:     {test_accuracy * 100:.2f}%")
print(f"   Difference:        {abs(train_accuracy - test_accuracy) * 100:.2f}%")
print("="*60)
# Out:
# Evaluating the model on the test set...
# 63/63 - 0s - 3ms/step - accuracy: 0.9470 - loss: 0.1859
#
# ============================================================
# 🎯 Training Accuracy: 95.11%
# 🎯 Test Accuracy:     94.70%
#    Difference:        0.41%
# ============================================================

# %%
model.save('D:\\amrita intern\\5 split data\\saved_models\\weight_exchg_2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
